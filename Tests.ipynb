# %%
import sys
import datetime
import numpy as np
from tqdm import tqdm
from stable_baselines3 import DQN
from utils import evaluate as ev
from utils import evaluate_extended as ev2
import gym
import sqli_sim

# %%
env_name = 'sqli_sim-v0'

# %%
n_simulations = 1
n_episodes_training = 10 ** 6
n_episodes_test = 10 ** 2

# %% [markdown]
# ## Running the simulations on escape = 5 columns = 5

# %%
env = gym.make(env_name, escapes=5, columns=5)
model1 = [DQN('MlpPolicy', env, verbose=1) for i in range(n_simulations)]
print(model1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# [<stable_baselines3.dqn.dqn.DQN object at 0x134f2b070>]

# %%
train_data = np.zeros((n_simulations, 3, n_episodes_training))
test_data = np.zeros((n_simulations, 3, n_episodes_test))

for i in tqdm(range(n_simulations)):
    model1[i].learn(total_timesteps=10 ** 6)
    model1[i].save(str(i) + 'ignore_test1')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73       |
# |    ep_rew_mean      | -62      |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 23961    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 292      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.1     |
# |    ep_rew_mean      | -86.1    |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 25761    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 777      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -101     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 27402    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.4     |
# |    ep_rew_mean      | -86.4    |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 27098    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -80      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 26908    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1821     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.2     |
# |    ep_rew_mean      | -75.2    |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 26538    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2068     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.5     |
# |    ep_rew_mean      | -68.5    |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 26280    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.3     |
# |    ep_rew_mean      | -73.3    |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 26559    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2697     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.4     |
# |    ep_rew_mean      | -70.4    |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 26600    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2931     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.6     |
# |    ep_rew_mean      | -67.6    |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 26637    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3145     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.2     |
# |    ep_rew_mean      | -65.2    |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 26690    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3354     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.7     |
# |    ep_rew_mean      | -66.7    |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 26672    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3728     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.9     |
# |    ep_rew_mean      | -64.9    |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 26470    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.9     |
# |    ep_rew_mean      | -74.9    |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 27353    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.6     |
# |    ep_rew_mean      | -74.6    |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 27415    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5138     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -78.2    |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 27632    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5710     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.7     |
# |    ep_rew_mean      | -75.7    |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 27545    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.6     |
# |    ep_rew_mean      | -76.6    |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 27672    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.6     |
# |    ep_rew_mean      | -77.6    |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 27813    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6731     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.5     |
# |    ep_rew_mean      | -76.5    |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 27673    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7002     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.9     |
# |    ep_rew_mean      | -74.9    |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 27601    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7218     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.8     |
# |    ep_rew_mean      | -75.8    |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 27553    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7634     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.3     |
# |    ep_rew_mean      | -74.3    |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 27511    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7844     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.7     |
# |    ep_rew_mean      | -72.7    |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 27464    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8035     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82       |
# |    ep_rew_mean      | -71      |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 27426    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8201     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.1     |
# |    ep_rew_mean      | -70.1    |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 27327    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8403     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.6     |
# |    ep_rew_mean      | -67.6    |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 27217    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8637     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.6     |
# |    ep_rew_mean      | -63.6    |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 27103    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.8     |
# |    ep_rew_mean      | -63.8    |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 27051    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.9     |
# |    ep_rew_mean      | -63.9    |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 27080    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9311     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76       |
# |    ep_rew_mean      | -65      |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 27135    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.7     |
# |    ep_rew_mean      | -64.7    |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 27089    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9792     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.6     |
# |    ep_rew_mean      | -62.6    |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 26838    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.7     |
# |    ep_rew_mean      | -64.7    |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 26967    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.5     |
# |    ep_rew_mean      | -64.5    |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 26882    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10700    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.8     |
# |    ep_rew_mean      | -64.8    |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 26867    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.9     |
# |    ep_rew_mean      | -64.9    |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 26924    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11321    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.1     |
# |    ep_rew_mean      | -65.1    |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 26918    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.4     |
# |    ep_rew_mean      | -59.4    |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 26886    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71       |
# |    ep_rew_mean      | -60      |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 26946    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12233    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.1     |
# |    ep_rew_mean      | -59.1    |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 26976    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12717    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.2     |
# |    ep_rew_mean      | -60.2    |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 26946    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13018    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71       |
# |    ep_rew_mean      | -60      |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 26949    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69       |
# |    ep_rew_mean      | -58      |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 26937    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13635    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.2     |
# |    ep_rew_mean      | -57.2    |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 26919    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.7     |
# |    ep_rew_mean      | -58.7    |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 26971    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14187    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.7     |
# |    ep_rew_mean      | -55.7    |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 26944    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14301    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.9     |
# |    ep_rew_mean      | -59.9    |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 27060    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.9     |
# |    ep_rew_mean      | -60.9    |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 27047    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 15225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.7     |
# |    ep_rew_mean      | -62.7    |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 27098    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 15569    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.1     |
# |    ep_rew_mean      | -66.1    |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 27155    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16113    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.5     |
# |    ep_rew_mean      | -67.5    |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 27055    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16487    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.1     |
# |    ep_rew_mean      | -69.1    |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 27023    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16817    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.5     |
# |    ep_rew_mean      | -67.5    |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 26971    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16891    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.7     |
# |    ep_rew_mean      | -67.7    |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 26968    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 17177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82       |
# |    ep_rew_mean      | -71      |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 27060    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 17867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.2     |
# |    ep_rew_mean      | -73.2    |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 27027    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 18217    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.4     |
# |    ep_rew_mean      | -74.4    |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 26984    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 18592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.6     |
# |    ep_rew_mean      | -71.6    |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 26929    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 18759    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.9     |
# |    ep_rew_mean      | -72.9    |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 26862    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 19088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -78.9    |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 27005    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 19922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.7     |
# |    ep_rew_mean      | -76.7    |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 26959    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.8     |
# |    ep_rew_mean      | -75.8    |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 26926    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.1     |
# |    ep_rew_mean      | -74.1    |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 26761    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.8     |
# |    ep_rew_mean      | -71.8    |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 26721    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20516    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | -70      |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 26716    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20814    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.8     |
# |    ep_rew_mean      | -70.8    |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 26754    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 21202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.6     |
# |    ep_rew_mean      | -68.6    |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 26761    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 21363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.4     |
# |    ep_rew_mean      | -68.4    |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 26744    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 21577    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.8     |
# |    ep_rew_mean      | -70.8    |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 26810    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 21994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84       |
# |    ep_rew_mean      | -73      |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 26887    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 22586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.2     |
# |    ep_rew_mean      | -76.2    |
# |    exploration_rate | 0.781    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 26950    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.5     |
# |    ep_rew_mean      | -71.5    |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 26918    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.8     |
# |    ep_rew_mean      | -71.8    |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 26907    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23507    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.6     |
# |    ep_rew_mean      | -73.6    |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 26963    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24027    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86       |
# |    ep_rew_mean      | -75      |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 27044    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24717    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.2     |
# |    ep_rew_mean      | -73.2    |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 27041    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24907    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.8     |
# |    ep_rew_mean      | -75.8    |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 27140    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25497    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -79.7    |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 27191    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -81.6    |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 27224    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 26437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.2     |
# |    ep_rew_mean      | -76.2    |
# |    exploration_rate | 0.747    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 27195    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 26585    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.5     |
# |    ep_rew_mean      | -75.5    |
# |    exploration_rate | 0.745    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 27201    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 26862    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.1     |
# |    ep_rew_mean      | -73.1    |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 27151    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 27006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.7     |
# |    ep_rew_mean      | -74.7    |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 27145    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 27324    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | -77.5    |
# |    exploration_rate | 0.735    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 27188    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 27938    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.1     |
# |    ep_rew_mean      | -71.1    |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 27178    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 28134    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81       |
# |    ep_rew_mean      | -70      |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 27158    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 28194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.9     |
# |    ep_rew_mean      | -73.9    |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 27145    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 28729    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.2     |
# |    ep_rew_mean      | -76.2    |
# |    exploration_rate | 0.724    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 27175    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 29076    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -77.9    |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 27187    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 29408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.7     |
# |    ep_rew_mean      | -76.7    |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 27175    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 29588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -78.5    |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 27228    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 30151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -83.2    |
# |    exploration_rate | 0.708    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 27288    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 30788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | -85.9    |
# |    exploration_rate | 0.703    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 27322    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 31270    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -84.5    |
# |    exploration_rate | 0.7      |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 27330    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 31540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -82.7    |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 27361    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 31957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -80.7    |
# |    exploration_rate | 0.694    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 27369    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 32197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -81.6    |
# |    exploration_rate | 0.692    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 27372    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 32451    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -82.2    |
# |    exploration_rate | 0.688    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 27388    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 32822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -78.5    |
# |    exploration_rate | 0.687    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 27369    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 32974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.6     |
# |    ep_rew_mean      | -73.6    |
# |    exploration_rate | 0.685    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 27351    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 33179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.9     |
# |    ep_rew_mean      | -75.9    |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 27393    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 33601    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83       |
# |    ep_rew_mean      | -72      |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 27387    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 33797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.2     |
# |    ep_rew_mean      | -72.2    |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 27425    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 34280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.7     |
# |    ep_rew_mean      | -70.7    |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 27428    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 34602    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.2     |
# |    ep_rew_mean      | -72.2    |
# |    exploration_rate | 0.668    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 27427    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 34908    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.1     |
# |    ep_rew_mean      | -75.1    |
# |    exploration_rate | 0.663    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 27474    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 35469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.2     |
# |    ep_rew_mean      | -77.2    |
# |    exploration_rate | 0.66     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 27502    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 35831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.6     |
# |    ep_rew_mean      | -76.6    |
# |    exploration_rate | 0.657    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 27498    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 36080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.3     |
# |    ep_rew_mean      | -72.3    |
# |    exploration_rate | 0.655    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 27488    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 36264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.7     |
# |    ep_rew_mean      | -72.7    |
# |    exploration_rate | 0.653    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 27483    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 36505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.7     |
# |    ep_rew_mean      | -75.7    |
# |    exploration_rate | 0.65     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 27494    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 36859    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.1     |
# |    ep_rew_mean      | -74.1    |
# |    exploration_rate | 0.646    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 27503    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 37237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.5     |
# |    ep_rew_mean      | -73.5    |
# |    exploration_rate | 0.643    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 27506    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 37529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85       |
# |    ep_rew_mean      | -74      |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 27530    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 37913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.9     |
# |    ep_rew_mean      | -73.9    |
# |    exploration_rate | 0.638    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 27525    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38077    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 80.8     |
# |    ep_rew_mean      | -69.8    |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 27509    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78.6     |
# |    ep_rew_mean      | -67.6    |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 27527    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38647    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.2     |
# |    ep_rew_mean      | -65.2    |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 27526    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 77.2     |
# |    ep_rew_mean      | -66.2    |
# |    exploration_rate | 0.627    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 27534    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 39259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.4     |
# |    ep_rew_mean      | -65.4    |
# |    exploration_rate | 0.624    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 27549    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 39600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76       |
# |    ep_rew_mean      | -65      |
# |    exploration_rate | 0.622    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 27534    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 39800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.6     |
# |    ep_rew_mean      | -64.6    |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 27514    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 40009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76       |
# |    ep_rew_mean      | -65      |
# |    exploration_rate | 0.616    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 27514    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 40421    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.2     |
# |    ep_rew_mean      | -65.2    |
# |    exploration_rate | 0.614    |
# | time/               |          |
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0354   |
# |    n_updates        | 228678   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 324      |
# |    ep_rew_mean      | -313     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3540     |
# |    fps              | 836      |
# |    time_elapsed     | 1153     |
# |    total_timesteps  | 965558   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00885  |
# |    n_updates        | 228889   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 322      |
# |    ep_rew_mean      | -311     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3544     |
# |    fps              | 836      |
# |    time_elapsed     | 1154     |
# |    total_timesteps  | 966353   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 229088   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 312      |
# |    ep_rew_mean      | -301     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3548     |
# |    fps              | 836      |
# |    time_elapsed     | 1155     |
# |    total_timesteps  | 966572   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00507  |
# |    n_updates        | 229142   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 307      |
# |    ep_rew_mean      | -296     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3552     |
# |    fps              | 836      |
# |    time_elapsed     | 1156     |
# |    total_timesteps  | 967614   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64     |
# |    n_updates        | 229403   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 309      |
# |    ep_rew_mean      | -298     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3556     |
# |    fps              | 836      |
# |    time_elapsed     | 1158     |
# |    total_timesteps  | 968742   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 229685   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 315      |
# |    ep_rew_mean      | -304     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3560     |
# |    fps              | 836      |
# |    time_elapsed     | 1160     |
# |    total_timesteps  | 970813   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00381  |
# |    n_updates        | 230203   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 321      |
# |    ep_rew_mean      | -310     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3564     |
# |    fps              | 836      |
# |    time_elapsed     | 1162     |
# |    total_timesteps  | 972241   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00685  |
# |    n_updates        | 230560   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | -283     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3568     |
# |    fps              | 835      |
# |    time_elapsed     | 1163     |
# |    total_timesteps  | 972946   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00601  |
# |    n_updates        | 230736   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 295      |
# |    ep_rew_mean      | -284     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3572     |
# |    fps              | 835      |
# |    time_elapsed     | 1164     |
# |    total_timesteps  | 973738   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00714  |
# |    n_updates        | 230934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | -287     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3576     |
# |    fps              | 835      |
# |    time_elapsed     | 1166     |
# |    total_timesteps  | 974977   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00532  |
# |    n_updates        | 231244   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 285      |
# |    ep_rew_mean      | -274     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3580     |
# |    fps              | 835      |
# |    time_elapsed     | 1169     |
# |    total_timesteps  | 976913   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.268    |
# |    n_updates        | 231728   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 283      |
# |    ep_rew_mean      | -272     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3584     |
# |    fps              | 835      |
# |    time_elapsed     | 1170     |
# |    total_timesteps  | 977682   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.33     |
# |    n_updates        | 231920   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 286      |
# |    ep_rew_mean      | -275     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3588     |
# |    fps              | 835      |
# |    time_elapsed     | 1171     |
# |    total_timesteps  | 978622   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.142    |
# |    n_updates        | 232155   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 290      |
# |    ep_rew_mean      | -279     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3592     |
# |    fps              | 835      |
# |    time_elapsed     | 1173     |
# |    total_timesteps  | 979993   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00498  |
# |    n_updates        | 232498   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 295      |
# |    ep_rew_mean      | -284     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3596     |
# |    fps              | 834      |
# |    time_elapsed     | 1175     |
# |    total_timesteps  | 981593   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 232898   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | -282     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3600     |
# |    fps              | 834      |
# |    time_elapsed     | 1176     |
# |    total_timesteps  | 982246   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00346  |
# |    n_updates        | 233061   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 287      |
# |    ep_rew_mean      | -276     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3604     |
# |    fps              | 834      |
# |    time_elapsed     | 1177     |
# |    total_timesteps  | 983211   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 233302   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 285      |
# |    ep_rew_mean      | -274     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3608     |
# |    fps              | 834      |
# |    time_elapsed     | 1179     |
# |    total_timesteps  | 984042   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00532  |
# |    n_updates        | 233510   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 287      |
# |    ep_rew_mean      | -276     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3612     |
# |    fps              | 834      |
# |    time_elapsed     | 1180     |
# |    total_timesteps  | 985126   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37     |
# |    n_updates        | 233781   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 283      |
# |    ep_rew_mean      | -272     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3616     |
# |    fps              | 834      |
# |    time_elapsed     | 1182     |
# |    total_timesteps  | 986329   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00415  |
# |    n_updates        | 234082   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 286      |
# |    ep_rew_mean      | -275     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3620     |
# |    fps              | 833      |
# |    time_elapsed     | 1185     |
# |    total_timesteps  | 988233   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.039    |
# |    n_updates        | 234558   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 276      |
# |    ep_rew_mean      | -265     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3624     |
# |    fps              | 833      |
# |    time_elapsed     | 1185     |
# |    total_timesteps  | 988637   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00816  |
# |    n_updates        | 234659   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 275      |
# |    ep_rew_mean      | -264     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3628     |
# |    fps              | 833      |
# |    time_elapsed     | 1187     |
# |    total_timesteps  | 989809   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00766  |
# |    n_updates        | 234952   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 282      |
# |    ep_rew_mean      | -271     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3632     |
# |    fps              | 833      |
# |    time_elapsed     | 1189     |
# |    total_timesteps  | 991370   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 235342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 272      |
# |    ep_rew_mean      | -261     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3636     |
# |    fps              | 833      |
# |    time_elapsed     | 1190     |
# |    total_timesteps  | 991868   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 235466   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 272      |
# |    ep_rew_mean      | -262     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3640     |
# |    fps              | 833      |
# |    time_elapsed     | 1191     |
# |    total_timesteps  | 992808   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00594  |
# |    n_updates        | 235701   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 280      |
# |    ep_rew_mean      | -269     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3644     |
# |    fps              | 832      |
# |    time_elapsed     | 1193     |
# |    total_timesteps  | 994381   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00299  |
# |    n_updates        | 236095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 291      |
# |    ep_rew_mean      | -280     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3648     |
# |    fps              | 832      |
# |    time_elapsed     | 1195     |
# |    total_timesteps  | 995699   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0045   |
# |    n_updates        | 236424   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 304      |
# |    ep_rew_mean      | -293     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3652     |
# |    fps              | 832      |
# |    time_elapsed     | 1198     |
# |    total_timesteps  | 997989   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00476  |
# |    n_updates        | 236997   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 310      |
# |    ep_rew_mean      | -299     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3656     |
# |    fps              | 832      |
# |    time_elapsed     | 1200     |
# |    total_timesteps  | 999765   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00692  |
# |    n_updates        | 237441   |
# ----------------------------------
# 100%|██████████| 1/1 [20:01<00:00, 1201.03s/it]

# %%
for i in tqdm(range(n_simulations)):
    mean_reward, _ = ev.evaluate_model(model1[i].load(str(i) + 'ignore_test1'), env, num_steps=10 ** 6)
    print('dqn Mean reward: {0}'.format(mean_reward))
# Out:
# 100%|██████████| 1/1 [10:52<00:00, 652.71s/it]
# dqn Mean reward: -933.297

# %% [markdown]
# ## Running the simulations on escape = 3 columns = 10

# %%
env = gym.make(env_name, escapes=3, columns=10)
model2 = [DQN('MlpPolicy', env, verbose=1) for i in range(n_simulations)]
print(model2)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# [<stable_baselines3.dqn.dqn.DQN object at 0x134f64df0>]

# %%
train_data = np.zeros((n_simulations, 3, n_episodes_training))
test_data = np.zeros((n_simulations, 3, n_episodes_test))

for i in tqdm(range(n_simulations)):
    model2[i].learn(total_timesteps=10 ** 6)
    model2[i].save(str(i) + 'ignore_test2')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.8     |
# |    ep_rew_mean      | -49.8    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 20302    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.8     |
# |    ep_rew_mean      | -53.8    |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 22262    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 518      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.2     |
# |    ep_rew_mean      | -60.2    |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 21573    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 855      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.2     |
# |    ep_rew_mean      | -49.2    |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 20112    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 963      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.5     |
# |    ep_rew_mean      | -68.5    |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 22279    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.6     |
# |    ep_rew_mean      | -65.6    |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 22293    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1839     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.9     |
# |    ep_rew_mean      | -76.9    |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 23632    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2461     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.3     |
# |    ep_rew_mean      | -76.3    |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 23730    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.1     |
# |    ep_rew_mean      | -74.1    |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 23960    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3063     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -81.1    |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 24807    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -95.1    |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 25496    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4670     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -96.2    |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 25924    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5145     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -92.8    |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 25682    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -91.8    |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 25759    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -92.2    |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 25854    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -91.1    |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 25900    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6533     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.5     |
# |    ep_rew_mean      | -88.5    |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 25808    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6766     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -89.8    |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 25911    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7255     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -90      |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 26000    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -90.1    |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 26044    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8091     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -89.8    |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 26142    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | -88.2    |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 26091    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | -87.4    |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 26091    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.4     |
# |    ep_rew_mean      | -86.4    |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 26111    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -95.4    |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 26488    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10639    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -99      |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 26668    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11244    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 26870    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 26996    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12541    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 27091    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13109    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 27079    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13267    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 27089    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -101     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 27004    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 13684    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 27114    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 27032    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14725    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 26969    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 14940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -96      |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 27001    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 15369    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -98.4    |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 27170    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | -100     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 27194    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16507    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -99.4    |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 27209    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -97.7    |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 27216    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 17056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -98.6    |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 27217    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 17492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -99      |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 27206    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 17761    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -101     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 27309    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 18493    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -98.8    |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 27285    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 18657    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -99.2    |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 27275    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 19108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | -99.6    |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 27320    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 19523    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | -101     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 27296    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 19903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -103     |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 27300    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -104     |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 27322    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20807    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -95.5    |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 27362    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 21292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -94.1    |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 27409    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 21758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -88.8    |
# |    exploration_rate | 0.792    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 27395    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 21914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.9     |
# |    ep_rew_mean      | -86.9    |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 27393    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 22334    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.6     |
# |    ep_rew_mean      | -84.6    |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 27417    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 22670    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | -88.9    |
# |    exploration_rate | 0.779    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 27497    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23257    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | -88.2    |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 27484    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 23451    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -93.5    |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 27555    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | -87.4    |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 27542    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24415    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -88      |
# |    exploration_rate | 0.766    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 27501    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24623    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -93.8    |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 27616    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25418    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -93.9    |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 27640    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25856    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -90.4    |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 27661    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 26229    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.9     |
# |    ep_rew_mean      | -87.9    |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 27663    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 26397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.3     |
# |    ep_rew_mean      | -88.3    |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 27629    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 26724    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -90.9    |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 27664    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 27245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -89.2    |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 27645    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 27511    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -89.2    |
# |    exploration_rate | 0.736    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 27632    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 27776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.4     |
# |    ep_rew_mean      | -85.4    |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 27629    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 28133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.6     |
# |    ep_rew_mean      | -85.6    |
# |    exploration_rate | 0.731    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 27627    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 28318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -83.5    |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 27630    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 28560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | -83.6    |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 27651    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 28985    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -82      |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 27641    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 29201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -80.6    |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 27624    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 29582    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -78.9    |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 27610    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 29794    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.3     |
# |    ep_rew_mean      | -76.3    |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 27593    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 30024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.5     |
# |    ep_rew_mean      | -72.5    |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 27567    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 30104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.3     |
# |    ep_rew_mean      | -76.3    |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 27596    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 30641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.7     |
# |    ep_rew_mean      | -75.7    |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 27560    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 31007    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -77.7    |
# |    exploration_rate | 0.7      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 27582    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 31541    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -78.9    |
# |    exploration_rate | 0.694    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 27625    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 32250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -80.1    |
# |    exploration_rate | 0.691    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 27601    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 32558    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.8     |
# |    ep_rew_mean      | -76.8    |
# |    exploration_rate | 0.687    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 27571    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 32913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -80      |
# |    exploration_rate | 0.682    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 27599    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 33515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -81.3    |
# |    exploration_rate | 0.678    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 27613    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 33849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.5     |
# |    ep_rew_mean      | -76.5    |
# |    exploration_rate | 0.675    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 27616    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 34171    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.5     |
# |    ep_rew_mean      | -74.5    |
# |    exploration_rate | 0.673    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 27606    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 34403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.4     |
# |    ep_rew_mean      | -73.4    |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 27594    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 34669    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.3     |
# |    ep_rew_mean      | -75.3    |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 27608    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 35023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.9     |
# |    ep_rew_mean      | -74.9    |
# |    exploration_rate | 0.665    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 27616    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 35310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.4     |
# |    ep_rew_mean      | -73.4    |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 27621    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 35685    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86       |
# |    ep_rew_mean      | -75      |
# |    exploration_rate | 0.657    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 27640    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 36112    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.5     |
# |    ep_rew_mean      | -75.5    |
# |    exploration_rate | 0.654    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 27648    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 36421    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.8     |
# |    ep_rew_mean      | -75.8    |
# |    exploration_rate | 0.65     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 27662    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 36817    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -77.8    |
# |    exploration_rate | 0.647    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 27667    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 37198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -79.8    |
# |    exploration_rate | 0.642    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 27675    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 37637    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -83.5    |
# |    exploration_rate | 0.635    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 27721    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -82      |
# |    exploration_rate | 0.634    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 27699    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -80      |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 27682    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -78.4    |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 27666    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 38730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -83.7    |
# |    exploration_rate | 0.625    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 27739    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 39496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -93.1    |
# |    exploration_rate | 0.615    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 27810    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 40515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -92.2    |
# |    exploration_rate | 0.611    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 27814    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 40963    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -92.6    |
# |    exploration_rate | 0.607    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 27818    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 41365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -88.8    |
# |    exploration_rate | 0.606    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 27796    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 41522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | -84.3    |
# |    exploration_rate | 0.603    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 27789    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 41782    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -83.8    |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 27768    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 42042    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -82.6    |
# |    exploration_rate | 0.598    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 27758    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 42277    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -81.2    |
# |    exploration_rate | 0.594    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 27763    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 42735    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -78.8    |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 27750    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 42831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -78.9    |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 27753    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 43159    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -78.4    |
# |    exploration_rate | 0.588    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 27737    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 43347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -80.2    |
# |    exploration_rate | 0.584    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 27762    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 43792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -79      |
# |    exploration_rate | 0.582    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 27752    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 44018    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -83.1    |
# |    exploration_rate | 0.575    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 27798    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 44721    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -84.7    |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 27802    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 45250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -82.2    |
# |    exploration_rate | 0.568    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 27784    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 45436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | -83.6    |
# |    exploration_rate | 0.564    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 27797    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 45878    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -82.7    |
# |    exploration_rate | 0.561    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 27789    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 46188    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -82.2    |
# |    exploration_rate | 0.558    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 27798    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 46519    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | -84.9    |
# |    exploration_rate | 0.551    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 27830    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 47227    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -80.2    |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 27817    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 47561    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -80.7    |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 27800    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 47674    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -82.7    |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 27798    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 48048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -90.7    |
# |    exploration_rate | 0.535    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 27852    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 48901    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.9     |
# |    ep_rew_mean      | -87.9    |
# |    exploration_rate | 0.531    |
# | time/               |          |
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00837  |
# |    n_updates        | 222478   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 489      |
# |    ep_rew_mean      | -478     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2668     |
# |    fps              | 785      |
# |    time_elapsed     | 1198     |
# |    total_timesteps  | 941569   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 222892   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 487      |
# |    ep_rew_mean      | -476     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2672     |
# |    fps              | 785      |
# |    time_elapsed     | 1202     |
# |    total_timesteps  | 944494   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00273  |
# |    n_updates        | 223623   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 481      |
# |    ep_rew_mean      | -470     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2676     |
# |    fps              | 785      |
# |    time_elapsed     | 1206     |
# |    total_timesteps  | 947089   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00417  |
# |    n_updates        | 224272   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 491      |
# |    ep_rew_mean      | -480     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2680     |
# |    fps              | 785      |
# |    time_elapsed     | 1207     |
# |    total_timesteps  | 948522   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00982  |
# |    n_updates        | 224630   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -489     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2684     |
# |    fps              | 785      |
# |    time_elapsed     | 1211     |
# |    total_timesteps  | 950978   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00323  |
# |    n_updates        | 225244   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 503      |
# |    ep_rew_mean      | -492     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2688     |
# |    fps              | 784      |
# |    time_elapsed     | 1213     |
# |    total_timesteps  | 952593   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0023   |
# |    n_updates        | 225648   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 498      |
# |    ep_rew_mean      | -488     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2692     |
# |    fps              | 784      |
# |    time_elapsed     | 1215     |
# |    total_timesteps  | 954057   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 226014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 478      |
# |    ep_rew_mean      | -467     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2696     |
# |    fps              | 784      |
# |    time_elapsed     | 1216     |
# |    total_timesteps  | 954862   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0048   |
# |    n_updates        | 226215   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 463      |
# |    ep_rew_mean      | -452     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 784      |
# |    time_elapsed     | 1217     |
# |    total_timesteps  | 955641   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00554  |
# |    n_updates        | 226410   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 472      |
# |    ep_rew_mean      | -461     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2704     |
# |    fps              | 784      |
# |    time_elapsed     | 1221     |
# |    total_timesteps  | 958345   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00425  |
# |    n_updates        | 227086   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 482      |
# |    ep_rew_mean      | -471     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2708     |
# |    fps              | 784      |
# |    time_elapsed     | 1224     |
# |    total_timesteps  | 960657   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00337  |
# |    n_updates        | 227664   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 488      |
# |    ep_rew_mean      | -477     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2712     |
# |    fps              | 784      |
# |    time_elapsed     | 1227     |
# |    total_timesteps  | 962611   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.69     |
# |    n_updates        | 228152   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 486      |
# |    ep_rew_mean      | -475     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2716     |
# |    fps              | 784      |
# |    time_elapsed     | 1228     |
# |    total_timesteps  | 963799   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00345  |
# |    n_updates        | 228449   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 443      |
# |    ep_rew_mean      | -432     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2720     |
# |    fps              | 784      |
# |    time_elapsed     | 1231     |
# |    total_timesteps  | 965465   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0047   |
# |    n_updates        | 228866   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | -450     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2724     |
# |    fps              | 783      |
# |    time_elapsed     | 1235     |
# |    total_timesteps  | 968246   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00365  |
# |    n_updates        | 229561   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 461      |
# |    ep_rew_mean      | -450     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2728     |
# |    fps              | 783      |
# |    time_elapsed     | 1236     |
# |    total_timesteps  | 968973   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00502  |
# |    n_updates        | 229743   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 458      |
# |    ep_rew_mean      | -447     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2732     |
# |    fps              | 783      |
# |    time_elapsed     | 1237     |
# |    total_timesteps  | 970293   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00693  |
# |    n_updates        | 230073   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 462      |
# |    ep_rew_mean      | -451     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2736     |
# |    fps              | 783      |
# |    time_elapsed     | 1239     |
# |    total_timesteps  | 971225   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00256  |
# |    n_updates        | 230306   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | -449     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2740     |
# |    fps              | 783      |
# |    time_elapsed     | 1242     |
# |    total_timesteps  | 973837   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.71     |
# |    n_updates        | 230959   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 471      |
# |    ep_rew_mean      | -460     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2744     |
# |    fps              | 783      |
# |    time_elapsed     | 1245     |
# |    total_timesteps  | 975665   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00738  |
# |    n_updates        | 231416   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 480      |
# |    ep_rew_mean      | -469     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2748     |
# |    fps              | 783      |
# |    time_elapsed     | 1247     |
# |    total_timesteps  | 977890   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 231972   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 469      |
# |    ep_rew_mean      | -458     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2752     |
# |    fps              | 783      |
# |    time_elapsed     | 1250     |
# |    total_timesteps  | 979558   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00322  |
# |    n_updates        | 232389   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 485      |
# |    ep_rew_mean      | -474     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2756     |
# |    fps              | 783      |
# |    time_elapsed     | 1255     |
# |    total_timesteps  | 983266   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.72     |
# |    n_updates        | 233316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 453      |
# |    ep_rew_mean      | -442     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2760     |
# |    fps              | 783      |
# |    time_elapsed     | 1255     |
# |    total_timesteps  | 983949   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00274  |
# |    n_updates        | 233487   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 457      |
# |    ep_rew_mean      | -446     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2764     |
# |    fps              | 783      |
# |    time_elapsed     | 1258     |
# |    total_timesteps  | 985653   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00751  |
# |    n_updates        | 233913   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 474      |
# |    ep_rew_mean      | -463     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2768     |
# |    fps              | 783      |
# |    time_elapsed     | 1262     |
# |    total_timesteps  | 989017   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00313  |
# |    n_updates        | 234754   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 469      |
# |    ep_rew_mean      | -458     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2772     |
# |    fps              | 783      |
# |    time_elapsed     | 1265     |
# |    total_timesteps  | 991353   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00502  |
# |    n_updates        | 235338   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 478      |
# |    ep_rew_mean      | -467     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2776     |
# |    fps              | 783      |
# |    time_elapsed     | 1270     |
# |    total_timesteps  | 994893   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00342  |
# |    n_updates        | 236223   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 489      |
# |    ep_rew_mean      | -478     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2780     |
# |    fps              | 783      |
# |    time_elapsed     | 1273     |
# |    total_timesteps  | 997446   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00351  |
# |    n_updates        | 236861   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 475      |
# |    ep_rew_mean      | -464     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2784     |
# |    fps              | 783      |
# |    time_elapsed     | 1274     |
# |    total_timesteps  | 998485   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00654  |
# |    n_updates        | 237121   |
# ----------------------------------
# 100%|██████████| 1/1 [21:16<00:00, 1276.98s/it]

# %%
for i in tqdm(range(n_simulations)):
    mean_reward, _ = ev.evaluate_model(model2[i].load(str(i) + 'ignore_test2'), env, num_steps=10 ** 6)
    print('dqn Mean reward: {0}'.format(mean_reward))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
